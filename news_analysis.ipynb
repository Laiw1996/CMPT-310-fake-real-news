# %%
import preprocessing

import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
from sklearn.cross_validation import train_test_split
from sklearn.model_selection import StratifiedKFold

import numpy as np
import os
import re
import pickle as pkl
import collections
import codecs
from functools import reduce
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# nltk.download('stopwords')
# nltk.download('punkt')
# nltk.download('wordnet')

# replace this with your data directory
data_dir = '/Users/luu22/Desktop/fake-real-news/train'

# this is where you would store your pickle
pkl_dir = '/Users/luu22/Desktop/fake-real-news/pickle'

preprocessing.load_data(data_dir)
preprocessing.process_content(pkl_dir)

# %%
with open(pkl_dir + '/processed.pickle', 'rb') as f:
    data = pkl.load(f)
    contents = data['contents']
    labels = data['labels']

# %%
vocabulary_size = 20000

all_words = reduce(lambda w1, w2: w1 + w2, contents)
word_num = len(all_words)
print('There are {} words in the dataset'.format(word_num))

count = [['UNK', -1]]
count.extend(collections.Counter(all_words).most_common(vocabulary_size - 1))
# Out:
# There are 1304658 words in the dataset

# %%
len(count)
# Out:
# 20000

# %%
dictionary = dict()
for word, _ in count:
    dictionary[word] = len(dictionary)
    
dictionary
# Out:
# {'UNK': 0,
#  'trump': 1,
#  'said': 2,
#  'clinton': 3,
#  'state': 4,
#  'u': 5,
#  'would': 6,
#  'one': 7,
#  'people': 8,
#  'year': 9,
#  'new': 10,
#  'republican': 11,
#  'time': 12,
#  'president': 13,
#  'obama': 14,
#  'american': 15,
#  'also': 16,
#  'campaign': 17,
#  'hillary': 18,
#  'like': 19,
#  'say': 20,
#  'election': 21,
#  'party': 22,
#  'could': 23,
#  'even': 24,
#  'country': 25,
#  'right': 26,
#  'many': 27,
#  'two': 28,
#  'government': 29,
#  'day': 30,
#  'candidate': 31,
#  'first': 32,
#  'political': 33,
#  'get': 34,
#  'make': 35,
#  'house': 36,
#  'way': 37,
#  'white': 38,
#  'world': 39,
#  'voter': 40,
#  'news': 41,
#  'vote': 42,
#  'know': 43,
#  'percent': 44,
#  'going': 45,
#  'think': 46,
#  'sander': 47,
#  'donald': 48,
#  'last': 49,
#  'war': 50,
#  'may': 51,
#  'presidential': 52,
#  'want': 53,
#  'democratic': 54,
#  'take': 55,
#  'policy': 56,
#  'much': 57,
#  'told': 58,
#  'law': 59,
#  'well': 60,
#  'email': 61,
#  'united': 62,
#  'medium': 63,
#  'group': 64,
#  'america': 65,
#  'back': 66,
#  'week': 67,
#  'support': 68,
#  'national': 69,
#  'go': 70,
#  'former': 71,
#  'democrat': 72,
#  'see': 73,
#  'official': 74,
#  'thing': 75,
#  'issue': 76,
#  'come': 77,
#  'need': 78,
#  'made': 79,
#  'woman': 80,
#  'still': 81,
#  'million': 82,
#  'life': 83,
#  'since': 84,
#  'point': 85,
#  'attack': 86,
#  'power': 87,
#  'work': 88,
#  'police': 89,
#  'public': 90,
#  'part': 91,
#  'case': 92,
#  'bill': 93,
#  'report': 94,
#  'debate': 95,
#  'according': 96,
#  'change': 97,
#  'bush': 98,
#  'gop': 99,
#  'poll': 100,
#  'court': 101,
#  'month': 102,
#  'leader': 103,
#  'washington': 104,
#  'cruz': 105,
#  'another': 106,
#  'long': 107,
#  'nation': 108,
#  'force': 109,
#  'win': 110,
#  'question': 111,
#  'russia': 112,
#  'security': 113,
#  'black': 114,
#  'system': 115,
#  'called': 116,
#  'fact': 117,
#  'conservative': 118,
#  'every': 119,
#  'good': 120,
#  'show': 121,
#  'fbi': 122,
#  'including': 123,
#  'race': 124,
#  'military': 125,
#  'never': 126,
#  'primary': 127,
#  'department': 128,
#  'congress': 129,
#  'next': 130,
#  'three': 131,
#  'member': 132,
#  'use': 133,
#  'end': 134,
#  'foreign': 135,
#  'deal': 136,
#  'mean': 137,
#  'number': 138,
#  'iran': 139,
#  'family': 140,
#  'around': 141,
#  'job': 142,
#  'among': 143,
#  'really': 144,
#  'federal': 145,
#  'york': 146,
#  'whether': 147,
#  'city': 148,
#  'look': 149,
#  'far': 150,
#  'plan': 151,
#  'might': 152,
#  'office': 153,
#  'post': 154,
#  'money': 155,
#  'left': 156,
#  'place': 157,
#  'administration': 158,
#  'help': 159,
#  'supporter': 160,
#  'put': 161,
#  'today': 162,
#  'call': 163,
#  'senate': 164,
#  'russian': 165,
#  'child': 166,
#  'saying': 167,
#  'justice': 168,
#  'already': 169,
#  'big': 170,
#  'john': 171,
#  'nominee': 172,
#  'secretary': 173,
#  'action': 174,
#  'likely': 175,
#  'used': 176,
#  'real': 177,
#  'problem': 178,
#  'top': 179,
#  'without': 180,
#  'le': 181,
#  'source': 182,
#  'high': 183,
#  'home': 184,
#  'speech': 185,
#  'general': 186,
#  'believe': 187,
#  'syria': 188,
#  'run': 189,
#  'found': 190,
#  'investigation': 191,
#  'health': 192,
#  'something': 193,
#  'though': 194,
#  'comment': 195,
#  'however': 196,
#  'lot': 197,
#  'tax': 198,
#  'program': 199,
#  'past': 200,
#  'night': 201,
#  'recent': 202,
#  'give': 203,
#  'free': 204,
#  'man': 205,
#  'yet': 206,
#  'better': 207,
#  'control': 208,
#  'least': 209,
#  'result': 210,
#  'rubio': 211,
#  'decision': 212,
#  'business': 213,
#  'clear': 214,
#  'tuesday': 215,
#  'information': 216,
#  'story': 217,
#  'term': 218,
#  'got': 219,
#  'act': 220,
#  'effort': 221,
#  'social': 222,
#  'politics': 223,
#  'october': 224,
#  'statement': 225,
#  'video': 226,
#  'let': 227,
#  'old': 228,
#  'history': 229,
#  'order': 230,
#  'cnn': 231,
#  'reason': 232,
#  'sen': 233,
#  'second': 234,
#  'school': 235,
#  'press': 236,
#  'matter': 237,
#  'become': 238,
#  'economic': 239,
#  'important': 240,
#  'early': 241,
#  'claim': 242,
#  'away': 243,
#  'november': 244,
#  'talk': 245,
#  'must': 246,
#  'com': 247,
#  'little': 248,
#  'came': 249,
#  'event': 250,
#  'lead': 251,
#  'asked': 252,
#  'great': 253,
#  'university': 254,
#  'nuclear': 255,
#  'interest': 256,
#  'voting': 257,
#  'actually': 258,
#  'working': 259,
#  'best': 260,
#  'four': 261,
#  'others': 262,
#  'ever': 263,
#  'find': 264,
#  'fox': 265,
#  'paul': 266,
#  'keep': 267,
#  'enough': 268,
#  'mr': 269,
#  'several': 270,
#  'care': 271,
#  'gun': 272,
#  'committee': 273,
#  'community': 274,
#  'idea': 275,
#  'anti': 276,
#  'process': 277,
#  'across': 278,
#  'side': 279,
#  'level': 280,
#  'line': 281,
#  'took': 282,
#  'view': 283,
#  'making': 284,
#  'ago': 285,
#  'company': 286,
#  'major': 287,
#  'different': 288,
#  'hand': 289,
#  'south': 290,
#  'word': 291,
#  'street': 292,
#  'behind': 293,
#  'face': 294,
#  'senator': 295,
#  'given': 296,
#  'center': 297,
#  'name': 298,
#  'seen': 299,
#  'interview': 300,
#  'majority': 301,
#  'director': 302,
#  'course': 303,
#  'area': 304,
#  'based': 305,
#  'isi': 306,
#  'death': 307,
#  'officer': 308,
#  'later': 309,
#  'delegate': 310,
#  'terrorist': 311,
#  'set': 312,
#  'running': 313,
#  'stop': 314,
#  'reported': 315,
#  'wednesday': 316,
#  'nothing': 317,
#  'iowa': 318,
#  'rule': 319,
#  'middle': 320,
#  'market': 321,
#  'global': 322,
#  'hard': 323,
#  'r': 324,
#  'record': 325,
#  'economy': 326,
#  'kind': 327,
#  'possible': 328,
#  'muslim': 329,
#  'private': 330,
#  'convention': 331,
#  'florida': 332,
#  'thursday': 333,
#  'service': 334,
#  'trying': 335,
#  'done': 336,
#  'hour': 337,
#  'al': 338,
#  'international': 339,
#  'person': 340,
#  'position': 341,
#  'fight': 342,
#  'rate': 343,
#  'threat': 344,
#  'close': 345,
#  'north': 346,
#  'friday': 347,
#  'foundation': 348,
#  'share': 349,
#  'iraq': 350,
#  'future': 351,
#  'evidence': 352,
#  'immigration': 353,
#  'trade': 354,
#  'move': 355,
#  'human': 356,
#  'israel': 357,
#  'establishment': 358,
#  'wall': 359,
#  'authority': 360,
#  'instead': 361,
#  'taking': 362,
#  'agency': 363,
#  'nomination': 364,
#  'hope': 365,
#  'monday': 366,
#  'added': 367,
#  'class': 368,
#  'liberal': 369,
#  'often': 370,
#  'always': 371,
#  'third': 372,
#  'weapon': 373,
#  'comey': 374,
#  'victory': 375,
#  'islamic': 376,
#  'anything': 377,
#  'tell': 378,
#  'crime': 379,
#  'almost': 380,
#  'wrote': 381,
#  'front': 382,
#  'continue': 383,
#  'pay': 384,
#  'start': 385,
#  'governor': 386,
#  'decade': 387,
#  'known': 388,
#  'able': 389,
#  'open': 390,
#  'twitter': 391,
#  'within': 392,
#  'sure': 393,
#  'example': 394,
#  'article': 395,
#  'feel': 396,
#  'study': 397,
#  'earlier': 398,
#  'head': 399,
#  'data': 400,
#  'water': 401,
#  'large': 402,
#  'meeting': 403,
#  'led': 404,
#  'defense': 405,
#  'small': 406,
#  'bernie': 407,
#  'someone': 408,
#  'citizen': 409,
#  'together': 410,
#  'team': 411,
#  'texas': 412,
#  'thought': 413,
#  'stand': 414,
#  'turn': 415,
#  'five': 416,
#  'sunday': 417,
#  'using': 418,
#  'organization': 419,
#  'men': 420,
#  'movement': 421,
#  'violence': 422,
#  'either': 423,
#  'chief': 424,
#  'true': 425,
#  'sign': 426,
#  'cost': 427,
#  'bank': 428,
#  'hold': 429,
#  'rather': 430,
#  'nearly': 431,
#  'young': 432,
#  'getting': 433,
#  'killed': 434,
#  'full': 435,
#  'book': 436,
#  'along': 437,
#  'personal': 438,
#  'executive': 439,
#  'hampshire': 440,
#  'energy': 441,
#  'rally': 442,
#  'facebook': 443,
#  'self': 444,
#  'gov': 445,
#  'role': 446,
#  'financial': 447,
#  'key': 448,
#  'supreme': 449,
#  'read': 450,
#  'taken': 451,
#  'moment': 452,
#  'late': 453,
#  'local': 454,
#  'despite': 455,
#  'following': 456,
#  'friend': 457,
#  'coming': 458,
#  'message': 459,
#  'went': 460,
#  'george': 461,
#  'reporter': 462,
#  'agreement': 463,
#  'live': 464,
#  'bad': 465,
#  'current': 466,
#  'anyone': 467,
#  'immigrant': 468,
#  'mind': 469,
#  'research': 470,
#  'looking': 471,
#  'individual': 472,
#  'cause': 473,
#  'ground': 474,
#  'legal': 475,
#  'concern': 476,
#  'strong': 477,
#  'risk': 478,
#  'thousand': 479,
#  'freedom': 480,
#  'shooting': 481,
#  'student': 482,
#  'intelligence': 483,
#  'th': 484,
#  'border': 485,
#  'half': 486,
#  'try': 487,
#  'seems': 488,
#  'college': 489,
#  'e': 490,
#  'billion': 491,
#  'criminal': 492,
#  'belief': 493,
#  'china': 494,
#  'ryan': 495,
#  'released': 496,
#  'potential': 497,
#  'elected': 498,
#  'presidency': 499,
#  'operation': 500,
#  'held': 501,
#  'reality': 502,
#  'non': 503,
#  'step': 504,
#  'talking': 505,
#  'field': 506,
#  'east': 507,
#  'kasich': 508,
#  'choice': 509,
#  'began': 510,
#  'protest': 511,
#  'union': 512,
#  'fear': 513,
#  'effect': 514,
#  'attorney': 515,
#  'probably': 516,
#  'civil': 517,
#  'barack': 518,
#  'simply': 519,
#  'west': 520,
#  'announced': 521,
#  'answer': 522,
#  'everyone': 523,
#  'especially': 524,
#  'play': 525,
#  'body': 526,
#  'account': 527,
#  'everything': 528,
#  'chance': 529,
#  'syrian': 530,
#  'ohio': 531,
#  'marriage': 532,
#  'minister': 533,
#  'outside': 534,
#  'response': 535,
#  'list': 536,
#  'politician': 537,
#  'reform': 538,
#  'speaker': 539,
#  'senior': 540,
#  'cut': 541,
#  'lost': 542,
#  'western': 543,
#  'benefit': 544,
#  'independent': 545,
#  'worker': 546,
#  'food': 547,
#  'challenge': 548,
#  'mass': 549,
#  'network': 550,
#  'march': 551,
#  'elite': 552,
#  'county': 553,
#  'leave': 554,
#  'common': 555,
#  'saudi': 556,
#  'dollar': 557,
#  'experience': 558,
#  'toward': 559,
#  'charge': 560,
#  'increase': 561,
#  'figure': 562,
#  'whose': 563,
#  'access': 564,
#  'morning': 565,
#  'carolina': 566,
#  'note': 567,
#  'low': 568,
#  'europe': 569,
#  'understand': 570,
#  'six': 571,
#  'ally': 572,
#  'strategy': 573,
#  'oil': 574,
#  'recently': 575,
#  'california': 576,
#  'crisis': 577,
#  'entire': 578,
#  'putin': 579,
#  'ballot': 580,
#  'drug': 581,
#  'terrorism': 582,
#  'vice': 583,
#  'secret': 584,
#  'c': 585,
#  'sense': 586,
#  'donor': 587,
#  'bring': 588,
#  'wrong': 589,
#  'industry': 590,
#  'illegal': 591,
#  'return': 592,
#  'perhaps': 593,
#  'saturday': 594,
#  'conference': 595,
#  'focus': 596,
#  'address': 597,
#  'air': 598,
#  'judge': 599,
#  'similar': 600,
#  'although': 601,
#  'church': 602,
#  'base': 603,
#  'ted': 604,
#  'attention': 605,
#  'whole': 606,
#  'truth': 607,
#  'region': 608,
#  'population': 609,
#  'serious': 610,
#  'sent': 611,
#  'started': 612,
#  'watch': 613,
#  'near': 614,
#  'shot': 615,
#  'stage': 616,
#  'site': 617,
#  'opportunity': 618,
#  'society': 619,
#  'christian': 620,
#  'form': 621,
#  'land': 622,
#  'happen': 623,
#  'opinion': 624,
#  'situation': 625,
#  'follow': 626,
#  'hit': 627,
#  'gave': 628,
#  'author': 629,
#  'failed': 630,
#  'became': 631,
#  'short': 632,
#  'income': 633,
#  'attempt': 634,
#  'religious': 635,
#  'special': 636,
#  'johnson': 637,
#  'climate': 638,
#  'project': 639,
#  'measure': 640,
#  'wikileaks': 641,
#  'david': 642,
#  'standing': 643,
#  'price': 644,
#  'parent': 645,
#  'love': 646,
#  'single': 647,
#  'caucus': 648,
#  'enforcement': 649,
#  'tried': 650,
#  'final': 651,
#  'daily': 652,
#  'rise': 653,
#  'wanted': 654,
#  'standard': 655,
#  'gold': 656,
#  'leading': 657,
#  'wife': 658,
#  'check': 659,
#  'expected': 660,
#  'spent': 661,
#  'else': 662,
#  'budget': 663,
#  'winning': 664,
#  'christie': 665,
#  'sex': 666,
#  'turned': 667,
#  'happened': 668,
#  'expert': 669,
#  'allow': 670,
#  'worked': 671,
#  'value': 672,
#  'latest': 673,
#  'leadership': 674,
#  'influence': 675,
#  'guy': 676,
#  'jeb': 677,
#  'raise': 678,
#  'democracy': 679,
#  'spending': 680,
#  'paid': 681,
#  'fighting': 682,
#  'letter': 683,
#  'fund': 684,
#  'server': 685,
#  'conflict': 686,
#  'involved': 687,
#  'longer': 688,
#  'chairman': 689,
#  'speaking': 690,
#  'romney': 691,
#  'particularly': 692,
#  'n': 693,
#  'father': 694,
#  'brain': 695,
#  'difference': 696,
#  'agent': 697,
#  'education': 698,
#  'target': 699,
#  'game': 700,
#  'pro': 701,
#  'nato': 702,
#  'forward': 703,
#  'w': 704,
#  'congressional': 705,
#  'age': 706,
#  'offer': 707,
#  'building': 708,
#  'district': 709,
#  'saw': 710,
#  'journalist': 711,
#  'minute': 712,
#  'european': 713,
#  'document': 714,
#  'yes': 715,
#  'fire': 716,
#  'published': 717,
#  'july': 718,
#  'higher': 719,
#  'image': 720,
#  'co': 721,
#  'beyond': 722,
#  'obamacare': 723,
#  'aide': 724,
#  'rest': 725,
#  'present': 726,
#  'biden': 727,
#  'significant': 728,
#  'regime': 729,
#  'god': 730,
#  'boehner': 731,
#  'paris': 732,
#  'showed': 733,
#  'needed': 734,
#  'ahead': 735,
#  'appeal': 736,
#  'calling': 737,
#  'staff': 738,
#  'army': 739,
#  'soon': 740,
#  'living': 741,
#  'create': 742,
#  'quite': 743,
#  'certainly': 744,
#  'test': 745,
#  'james': 746,
#  'peace': 747,
#  'http': 748,
#  'amount': 749,
#  'tv': 750,
#  'room': 751,
#  'battle': 752,
#  'contest': 753,
#  'phone': 754,
#  'heard': 755,
#  'african': 756,
#  'june': 757,
#  'detail': 758,
#  'century': 759,
#  'central': 760,
#  'argument': 761,
#  'host': 762,
#  'relation': 763,
#  'adviser': 764,
#  'crowd': 765,
#  'science': 766,
#  'board': 767,
#  'build': 768,
#  'begin': 769,
#  'fall': 770,
#  'carson': 771,
#  'seem': 772,
#  'electoral': 773,
#  'ukraine': 774,
#  'brought': 775,
#  'ask': 776,
#  'polling': 777,
#  'protect': 778,
#  'remains': 779,
#  'consider': 780,
#  'received': 781,
#  'described': 782,
#  'veteran': 783,
#  'super': 784,
#  'review': 785,
#  'mark': 786,
#  'opposition': 787,
#  'lie': 788,
#  'total': 789,
#  'directly': 790,
#  'dead': 791,
#  'related': 792,
#  'meet': 793,
#  'partisan': 794,
#  'due': 795,
#  'approach': 796,
#  'popular': 797,
#  'hundred': 798,
#  'inside': 799,
#  'growth': 800,
#  'helped': 801,
#  'culture': 802,
#  'activity': 803,
#  'town': 804,
#  'difficult': 805,
#  'ability': 806,
#  'worse': 807,
#  'biggest': 808,
#  'debt': 809,
#  'goal': 810,
#  'troop': 811,
#  'lose': 812,
#  'certain': 813,
#  'rep': 814,
#  'stay': 815,
#  'giving': 816,
#  'provide': 817,
#  'prison': 818,
#  'created': 819,
#  'voted': 820,
#  'noted': 821,
#  'development': 822,
#  'wing': 823,
#  'professor': 824,
#  'relationship': 825,
#  'decided': 826,
#  'finally': 827,
#  'trust': 828,
#  'include': 829,
#  'ready': 830,
#  'exactly': 831,
#  'couple': 832,
#  'michael': 833,
#  'appeared': 834,
#  'coalition': 835,
#  'agenda': 836,
#  'continued': 837,
#  'minority': 838,
#  'seemed': 839,
#  'maybe': 840,
#  'employee': 841,
#  'iranian': 842,
#  'machine': 843,
#  'mainstream': 844,
#  'brother': 845,
#  'release': 846,
#  'break': 847,
#  'opponent': 848,
#  'powerful': 849,
#  'chris': 850,
#  'star': 851,
#  'series': 852,
#  'cancer': 853,
#  'heart': 854,
#  'deep': 855,
#  'associated': 856,
#  'netanyahu': 857,
#  'september': 858,
#  'activist': 859,
#  'car': 860,
#  'affair': 861,
#  'indeed': 862,
#  'camp': 863,
#  'ruling': 864,
#  'planned': 865,
#  'upon': 866,
#  'posted': 867,
#  'husband': 868,
#  'appears': 869,
#  'page': 870,
#  'supporting': 871,
#  'massive': 872,
#  'impact': 873,
#  'paper': 874,
#  'alone': 875,
#  'claimed': 876,
#  'pretty': 877,
#  'israeli': 878,
#  'earth': 879,
#  'speak': 880,
#  'podesta': 881,
#  'son': 882,
#  'average': 883,
#  'loss': 884,
#  'resource': 885,
#  'prime': 886,
#  'meanwhile': 887,
#  'growing': 888,
#  'lawmaker': 889,
#  'rival': 890,
#  'clearly': 891,
#  'kid': 892,
#  'reach': 893,
#  'legislation': 894,
#  'penny': 895,
#  'capital': 896,
#  'radio': 897,
#  'generation': 898,
#  'period': 899,
#  'sort': 900,
#  'subject': 901,
#  'light': 902,
#  'wage': 903,
#  'representative': 904,
#  'mother': 905,
#  'promise': 906,
#  'corporate': 907,
#  'lack': 908,
#  'pipeline': 909,
#  'marco': 910,
#  'language': 911,
#  'immediately': 912,
#  'favor': 913,
#  'exchange': 914,
#  'voice': 915,
#  'january': 916,
#  'path': 917,
#  'changed': 918,
#  'cover': 919,
#  'gay': 920,
#  'condition': 921,
#  'mail': 922,
#  'allowed': 923,
#  'discussion': 924,
#  'door': 925,
#  'labor': 926,
#  'racist': 927,
#  'throughout': 928,
#  'spokesman': 929,
#  'remain': 930,
#  'huge': 931,
#  'eight': 932,
#  'french': 933,
#  'raised': 934,
#  'bomb': 935,
#  'enemy': 936,
#  'currently': 937,
#  'appear': 938,
#  'council': 939,
#  'lower': 940,
#  'killing': 941,
#  'particular': 942,
#  'king': 943,
#  'infowars': 944,
#  'progressive': 945,
#  'funding': 946,
#  'corruption': 947,
#  'terror': 948,
#  'palestinian': 949,
#  'add': 950,
#  'passed': 951,
#  'sanction': 952,
#  'firm': 953,
#  'spoke': 954,
#  'photo': 955,
#  'violent': 956,
#  'journal': 957,
#  'virginia': 958,
#  'hear': 959,
#  'august': 960,
#  'available': 961,
#  'protection': 962,
#  'fraud': 963,
#  'un': 964,
#  'analysis': 965,
#  'scandal': 966,
#  'doubt': 967,
#  'strike': 968,
#  'natural': 969,
#  'type': 970,
#  'mike': 971,
#  'dakota': 972,
#  'willing': 973,
#  'protester': 974,
#  'dangerous': 975,
#  'per': 976,
#  'usa': 977,
#  'beginning': 978,
#  'ad': 979,
#  'classified': 980,
#  'piece': 981,
#  'abortion': 982,
#  'eye': 983,
#  'victim': 984,
#  'alternative': 985,
#  'content': 986,
#  'hearing': 987,
#  'quickly': 988,
#  'possibility': 989,
#  'rock': 990,
#  'dozen': 991,
#  'joe': 992,
#  'previous': 993,
#  'continues': 994,
#  'showing': 995,
#  'felt': 996,
#  'website': 997,
#  'suggested': 998,
#  'included': 999,
#  ...}

# %%
# Smoothing: replace the infrequent words to UNKNOWN
for i, content in enumerate(contents):
        for word_idx, word in enumerate(content):
            if word in dictionary:
                index = dictionary[word]
            else:  # the word is considered as infrequent, represent using UNKNOWN
                index = 0
            contents[i][word_idx] = index

# %%
X = contents
y = data['labels']

# %%
print('---review---')
print(X[0])
print('---label---')
print(y[0])
# Out:
# ---review---
# [112, 4587, 5, 5571, 1086, 1758, 1343, 795, 1, 375, 6125, 10, 1578, 405, 10847, 94, 7281, 3530, 162, 4, 483, 1286, 115, 703, 471, 125, 470, 822, 0, 2235, 62, 4, 1758, 1343, 108, 937, 8887, 5571, 1086, 5, 1914, 552, 62, 8505, 740, 77, 29, 13, 1393, 48, 1, 567, 291, 2345, 3967, 1893, 94, 1979, 911, 16294, 165, 291, 2345, 2718, 3805, 96, 94, 0, 483, 1286, 5836, 418, 1192, 5572, 1105, 1333, 778, 3531, 69, 113, 256, 10847, 1241, 1611, 5571, 1086, 7, 16295, 344, 112, 578, 39, 10847, 403, 1369, 595, 339, 113, 94, 1759, 3531, 125, 1459, 4842, 5571, 1086, 10, 5, 713, 796, 3621, 596, 1700, 8506, 1086, 108, 137, 1879, 113, 256, 568, 427, 6851, 4279, 32, 543, 5571, 1086, 5705, 12371, 39, 94, 994, 12372, 498, 54, 29, 1932, 7055, 116, 2392, 1086, 667, 1612, 108, 543, 125, 3307, 1460, 18568, 86, 3531, 988, 7056, 2999, 130, 1339, 543, 5571, 1086, 94, 567, 774, 3390, 1086, 2934, 3268, 108, 12372, 498, 29, 849, 15, 330, 483, 363, 0, 6852, 2058, 1430, 116, 5350, 1993, 229, 19, 1932, 4665, 176, 520, 125, 3307, 3531, 94, 994, 520, 1460, 5571, 1086, 18569, 116, 0, 1086, 1136, 630, 657, 108, 18570, 5, 125, 1488, 9304, 1734, 520, 418, 5571, 1086, 108, 18571, 1525, 94, 20, 139, 1370, 1086, 112, 38, 5469, 1086, 389, 314, 1354, 3442, 253, 884, 83, 831, 520, 6126, 5351, 5571, 1086, 94, 1759, 133, 116, 503, 3806, 419, 5973, 418, 0, 4945, 298, 62, 4, 713, 512, 6, 4280, 12373, 82, 557, 1216, 0, 4433, 13, 579, 1348, 59, 3443, 9773, 174, 3531, 2901, 431, 543, 1063, 5573, 5571, 1086, 5973, 94, 758, 9305, 15, 1059, 461, 1032, 18572, 4433, 278, 39, 8124, 479, 2649, 83, 16, 575, 1792, 18, 3, 0, 4588, 174, 630, 1149, 238, 5, 13, 1747, 3531, 2650, 461, 1032, 404, 5, 1914, 1944, 5973, 5571, 1086, 94, 18573, 4587, 62, 4, 29, 238, 2577, 108, 39, 970, 4433, 3621, 684, 798, 419, 7520, 1311, 65, 108, 1242, 1379, 672, 912, 866, 48, 1, 498, 484, 13, 62, 4, 94, 4, 461, 1032, 1944, 5973, 1460, 8125, 5571, 1086, 2210, 1820, 13, 1, 6638, 65, 404, 461, 1032, 1944, 7521, 2346, 5973, 94, 994, 10, 5571, 1086, 2902, 15, 510, 1321, 479, 974, 2902, 431, 62, 4, 1071, 148, 988, 1162, 479, 3670, 737, 3584, 13, 1393, 48, 1, 583, 13, 1393, 971, 895, 55, 153, 1017, 1216, 232, 293, 511, 94, 1759, 13417, 3269, 956, 535, 5, 29, 109, 1193, 7816, 16296, 230, 415, 3670, 133, 394, 15, 29, 688, 2103, 941, 2649, 8, 1473, 246, 7055, 2578, 15, 8, 5571, 1086, 88, 94, 994, 2210, 49, 9, 19, 774, 282, 435, 9, 29, 7055, 1639, 232, 5571, 1086, 2282, 62, 4, 94, 758, 5, 1914, 552, 513, 13, 1393, 48, 1, 563, 509, 3968, 5042, 156, 713, 2966, 103, 1386, 3308, 7817, 1086, 1, 657, 740, 5706, 0, 569, 10, 21, 431, 3532, 7818, 12374, 32, 770, 1050, 740, 626, 563, 130, 103, 2601, 181, 3193, 5043, 7819, 10, 13, 5, 48, 1, 15, 8, 204, 5, 1454, 844, 63, 81, 3850, 668, 13, 1393, 48, 1, 375, 1585, 1669, 179, 1142, 218, 48, 1, 110, 94, 4, 2221, 1959, 3530, 483, 1286, 143, 2651, 39, 3851, 1355, 48, 1, 6, 110, 2869, 2088, 94, 123, 112, 6639, 14664, 1334, 995, 48, 1, 3444, 375, 165, 94, 4587, 15, 1086, 2579, 51, 49, 578, 387, 322, 6640, 1139, 48, 1, 1185, 484, 13, 62, 4, 94, 5707, 1241, 7522, 51, 94, 579, 4587, 125, 1459, 18, 3, 50, 13, 579, 2821, 7282, 0, 3756, 337, 285, 345, 4946, 39, 258, 15, 28, 509, 39, 50, 3852, 11545, 747, 3, 2841, 50, 1, 529, 97, 303, 227, 365, 13, 1, 862, 97, 303, 39, 2266, 4144, 1526, 182]
# ---label---
# 0

# %%
print('Maximum news length: {}'.format(
len(max((X), key=len))))
# Out:
# Maximum news length: 10290

# %%
print('Minimum news length: {}'.format(
len(min((X), key=len))))
# Out:
# Minimum news length: 2

# %%
lens = [len(s) for s in X]
print("average length: %0.1f" % np.mean(lens))
# Out:
# average length: 434.9

# %%
len(X)
# Out:
# 3000

# %%
from keras.preprocessing import sequence

# limit the maximum review length to max_words by truncating longer news and padding shorter news with a null value (0). 
max_words = 400
X_train = sequence.pad_sequences(X, maxlen=max_words)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### A simple Word2Vec CBOW model

# %%
from keras.layers import Dense, Input, Flatten
from keras.layers import GlobalAveragePooling1D, Embedding
from keras.models import Model
from keras.utils.np_utils import to_categorical

EMBEDDING_DIM = 50

# input: a sequence of MAX_SEQUENCE_LENGTH integers
def create_model():
    sequence_input = Input(shape=(max_words,))

    embedding_layer = Embedding(20000, EMBEDDING_DIM,
                            input_length=max_words,
                            trainable=True)
    embedded_sequences = embedding_layer(sequence_input)

    average = GlobalAveragePooling1D()(embedded_sequences)
    predictions = Dense(2, activation='softmax')(average)

    model = Model(sequence_input, predictions)
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam', 
                  metrics=['acc'])
    return model

# %%
avg_score1 = []

# %%
kfold = StratifiedKFold(n_splits=10, shuffle=True)

i = 0
y = np.array(y)
y_train = to_categorical(np.asarray(y))
cv_score = []


for train, test in kfold.split(X_train, y):
    model = create_model()
#     model.summary()
    print(X_train[0].shape)
    
    i += 1
    print("Running Fold", i, "/", 10)
    model.fit(X_train[train], y_train[train], batch_size=64, epochs=5, verbose=1)
    print("cross_validation score: ", model.evaluate(X_train[test], y_train[test], verbose=0)[1])
    cv_score.append(model.evaluate(X_train[test], y_train[test], verbose=0)[1])
avg_score1.append(sum(cv_score) / 10)
# Out:
# (400,)
# Running Fold 1 / 10
# Epoch 1/5
# 2700/2700 [==============================] - 2s 647us/step - loss: 0.6753 - acc: 0.6656
# Epoch 2/5
# 2700/2700 [==============================] - 1s 464us/step - loss: 0.6329 - acc: 0.7000
# Epoch 3/5
# 2700/2700 [==============================] - 1s 459us/step - loss: 0.5879 - acc: 0.7167
# Epoch 4/5
# 2700/2700 [==============================] - 1s 465us/step - loss: 0.5413 - acc: 0.7593
# Epoch 5/5
# 2700/2700 [==============================] - 1s 458us/step - loss: 0.4910 - acc: 0.8200
# cross_validation score:  0.8366666674613953
# (400,)
# Running Fold 2 / 10
# Epoch 1/5
# 2700/2700 [==============================] - 2s 653us/step - loss: 0.6736 - acc: 0.6737
# Epoch 2/5
# 2700/2700 [==============================] - 1s 456us/step - loss: 0.6302 - acc: 0.6926
# Epoch 3/5
# 2700/2700 [==============================] - 1s 450us/step - loss: 0.5849 - acc: 0.7193
# Epoch 4/5
# 2700/2700 [==============================] - 1s 496us/step - loss: 0.5381 - acc: 0.7674
# Epoch 5/5
# 2700/2700 [==============================] - 1s 466us/step - loss: 0.4889 - acc: 0.8233
# cross_validation score:  0.823333334128062
# (400,)
# Running Fold 3 / 10
# Epoch 1/5
# 2700/2700 [==============================] - 2s 726us/step - loss: 0.6717 - acc: 0.6767
# Epoch 2/5
# 2700/2700 [==============================] - 1s 509us/step - loss: 0.6232 - acc: 0.6970
# Epoch 3/5
# 2700/2700 [==============================] - 1s 467us/step - loss: 0.5770 - acc: 0.7204
# Epoch 4/5
# 2700/2700 [==============================] - 1s 457us/step - loss: 0.5301 - acc: 0.7778
# Epoch 5/5
# 2700/2700 [==============================] - 1s 460us/step - loss: 0.4806 - acc: 0.8337
# cross_validation score:  0.7966666674613953
# (400,)
# Running Fold 4 / 10
# Epoch 1/5
# 2700/2700 [==============================] - 2s 664us/step - loss: 0.6713 - acc: 0.6759
# Epoch 2/5
# 2700/2700 [==============================] - 1s 460us/step - loss: 0.6252 - acc: 0.6919
# Epoch 3/5
# 2700/2700 [==============================] - 1s 463us/step - loss: 0.5798 - acc: 0.7126
# Epoch 4/5
# 2700/2700 [==============================] - 2s 593us/step - loss: 0.5352 - acc: 0.7630
# Epoch 5/5
# 2700/2700 [==============================] - 2s 629us/step - loss: 0.4859 - acc: 0.8241
# cross_validation score:  0.7899999992052714
# (400,)
# Running Fold 5 / 10
# Epoch 1/5
# 2700/2700 [==============================] - 2s 820us/step - loss: 0.6738 - acc: 0.6707
# Epoch 2/5
# 2700/2700 [==============================] - 1s 490us/step - loss: 0.6285 - acc: 0.6985
# Epoch 3/5
# 2700/2700 [==============================] - 1s 435us/step - loss: 0.5816 - acc: 0.7181
# Epoch 4/5
# 2700/2700 [==============================] - 2s 559us/step - loss: 0.5361 - acc: 0.7648
# Epoch 5/5
# 2700/2700 [==============================] - 1s 483us/step - loss: 0.4883 - acc: 0.8196
# cross_validation score:  0.7766666666666666
# (400,)
# Running Fold 6 / 10
# Epoch 1/5
# 2700/2700 [==============================] - 2s 697us/step - loss: 0.6717 - acc: 0.6759
# Epoch 2/5
# 2700/2700 [==============================] - 1s 488us/step - loss: 0.6270 - acc: 0.6896
# Epoch 3/5
# 2700/2700 [==============================] - 2s 574us/step - loss: 0.5830 - acc: 0.7163
# Epoch 4/5
# 2700/2700 [==============================] - 1s 493us/step - loss: 0.5374 - acc: 0.7622
# Epoch 5/5
# 2700/2700 [==============================] - 1s 449us/step - loss: 0.4885 - acc: 0.8241
# cross_validation score:  0.83
# (400,)
# Running Fold 7 / 10
# Epoch 1/5
# 2700/2700 [==============================] - 2s 684us/step - loss: 0.6748 - acc: 0.6819
# Epoch 2/5
# 2700/2700 [==============================] - 1s 446us/step - loss: 0.6294 - acc: 0.6970
# Epoch 3/5
# 2700/2700 [==============================] - 1s 442us/step - loss: 0.5816 - acc: 0.7189
# Epoch 4/5
# 2700/2700 [==============================] - 1s 439us/step - loss: 0.5360 - acc: 0.7556
# Epoch 5/5
# 2700/2700 [==============================] - 1s 467us/step - loss: 0.4874 - acc: 0.8263
# cross_validation score:  0.8133333333333334
# (400,)
# Running Fold 8 / 10
# Epoch 1/5
# 2700/2700 [==============================] - 2s 786us/step - loss: 0.6711 - acc: 0.6800
# Epoch 2/5
# 2700/2700 [==============================] - 1s 474us/step - loss: 0.6220 - acc: 0.7011
# Epoch 3/5
# 2700/2700 [==============================] - 2s 614us/step - loss: 0.5765 - acc: 0.7237
# Epoch 4/5
# 2700/2700 [==============================] - 1s 478us/step - loss: 0.5303 - acc: 0.7756
# Epoch 5/5
# 2700/2700 [==============================] - 1s 485us/step - loss: 0.4807 - acc: 0.8344
# cross_validation score:  0.8533333341280619
# (400,)
# Running Fold 9 / 10
# Epoch 1/5
# 2700/2700 [==============================] - 2s 839us/step - loss: 0.6716 - acc: 0.6885
# Epoch 2/5
# 2700/2700 [==============================] - 1s 440us/step - loss: 0.6258 - acc: 0.7033
# Epoch 3/5
# 2700/2700 [==============================] - 1s 415us/step - loss: 0.5805 - acc: 0.7167
# Epoch 4/5
# 2700/2700 [==============================] - 1s 399us/step - loss: 0.5347 - acc: 0.7611
# Epoch 5/5
# 2700/2700 [==============================] - 1s 374us/step - loss: 0.4846 - acc: 0.8293
# cross_validation score:  0.796666665871938
# (400,)
# Running Fold 10 / 10
# Epoch 1/5
# 2700/2700 [==============================] - 2s 642us/step - loss: 0.6727 - acc: 0.6837
# Epoch 2/5
# 2700/2700 [==============================] - 1s 373us/step - loss: 0.6278 - acc: 0.6941
# Epoch 3/5
# 2700/2700 [==============================] - 1s 371us/step - loss: 0.5839 - acc: 0.7207
# Epoch 4/5
# 2700/2700 [==============================] - 1s 371us/step - loss: 0.5384 - acc: 0.7667
# Epoch 5/5
# 2700/2700 [==============================] - 1s 369us/step - loss: 0.4885 - acc: 0.8281
# cross_validation score:  0.8299999992052715

# %%
avg_score1
# Out:
# [0.8146666667461396]

# %% [markdown]
# ### A more complex model : CNN - LSTM

# %%
from keras.layers import LSTM, Conv1D, MaxPooling1D, Dropout

def create_cnn_lstm():
    # input: a sequence of 1000 integers
    sequence_input = Input(shape=(max_words,), dtype='int32')
    embedding_layer = Embedding(20000, EMBEDDING_DIM,
                        input_length=max_words,
                        trainable=True)
    embedded_sequences = embedding_layer(sequence_input)

    # 1D convolution with 64 output channels
    x = Conv1D(256, 5)(embedded_sequences)
    # MaxPool divides the length of the sequence by 5
    x = MaxPooling1D(5)(x)
    x = Dropout(0.2)(x)
    x = Conv1D(64, 5)(x)
    x = MaxPooling1D(5)(x)
    
    # LSTM layer with a hidden size of 64
    x = Dropout(0.2)(x)
    x = LSTM(16)(x)
    predictions = Dense(2, activation='softmax')(x)

    model = Model(sequence_input, predictions)
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['acc'])
    return model

# %%
avg_score2 = []

# %%
kfold = StratifiedKFold(n_splits=10, shuffle=True)

i = 0
y = np.array(y)
y_train = to_categorical(np.asarray(y))
cv_score = []

for train, test in kfold.split(X_train, y):
    model = create_cnn_lstm()
#     model.summary()
    print(X_train[0].shape)
#     print(test)
    
    i += 1
    print("Running Fold", i, "/", 10)
    model.fit(X_train[train], y_train[train], batch_size=64, epochs=6, verbose=1)
    print("cross_validation score: ", model.evaluate(X_train[test], y_train[test], verbose=0)[1])
    cv_score.append(model.evaluate(X_train[test], y_train[test], verbose=0)[1])
avg_score2.append(sum(cv_score) / 10)
# Out:
# (400,)
# Running Fold 1 / 10
# Epoch 1/6
# 2700/2700 [==============================] - 13s 5ms/step - loss: 0.5549 - acc: 0.7126
# Epoch 2/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.1992 - acc: 0.9152
# Epoch 3/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0801 - acc: 0.9681
# Epoch 4/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0410 - acc: 0.9881
# Epoch 5/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0227 - acc: 0.9956
# Epoch 6/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0123 - acc: 0.9993
# cross_validation score:  0.9033333333333333
# (400,)
# Running Fold 2 / 10
# Epoch 1/6
# 2700/2700 [==============================] - 13s 5ms/step - loss: 0.5633 - acc: 0.6944
# Epoch 2/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.2211 - acc: 0.9126
# Epoch 3/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.1023 - acc: 0.9611
# Epoch 4/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0478 - acc: 0.9841
# Epoch 5/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0247 - acc: 0.9944
# Epoch 6/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0142 - acc: 0.9985
# cross_validation score:  0.9033333333333333
# (400,)
# Running Fold 3 / 10
# Epoch 1/6
# 2700/2700 [==============================] - 14s 5ms/step - loss: 0.5675 - acc: 0.6930
# Epoch 2/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.2326 - acc: 0.9070
# Epoch 3/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0878 - acc: 0.9707
# Epoch 4/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0492 - acc: 0.9859
# Epoch 5/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0260 - acc: 0.9956
# Epoch 6/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0177 - acc: 0.9963
# cross_validation score:  0.8933333333333333
# (400,)
# Running Fold 4 / 10
# Epoch 1/6
# 2700/2700 [==============================] - 14s 5ms/step - loss: 0.5343 - acc: 0.7244
# Epoch 2/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.1928 - acc: 0.9148
# Epoch 3/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0734 - acc: 0.9730
# Epoch 4/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0499 - acc: 0.9804
# Epoch 5/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0369 - acc: 0.9844
# Epoch 6/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0258 - acc: 0.9930
# cross_validation score:  0.86
# (400,)
# Running Fold 5 / 10
# Epoch 1/6
# 2700/2700 [==============================] - 14s 5ms/step - loss: 0.5536 - acc: 0.7100
# Epoch 2/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.2221 - acc: 0.9081
# Epoch 3/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.1023 - acc: 0.9644
# Epoch 4/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0618 - acc: 0.9800
# Epoch 5/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0394 - acc: 0.9885
# Epoch 6/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0244 - acc: 0.9933
# cross_validation score:  0.92
# (400,)
# Running Fold 6 / 10
# Epoch 1/6
# 2700/2700 [==============================] - 14s 5ms/step - loss: 0.5640 - acc: 0.6937
# Epoch 2/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.2271 - acc: 0.9007
# Epoch 3/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0900 - acc: 0.9663
# Epoch 4/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0437 - acc: 0.9874
# Epoch 5/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0245 - acc: 0.9952
# Epoch 6/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0140 - acc: 0.9993
# cross_validation score:  0.91
# (400,)
# Running Fold 7 / 10
# Epoch 1/6
# 2700/2700 [==============================] - 14s 5ms/step - loss: 0.5472 - acc: 0.7096
# Epoch 2/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.2092 - acc: 0.9100
# Epoch 3/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0897 - acc: 0.9685
# Epoch 4/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0542 - acc: 0.9774
# Epoch 5/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0354 - acc: 0.9863
# Epoch 6/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0249 - acc: 0.9904
# cross_validation score:  0.9033333333333333
# (400,)
# Running Fold 8 / 10
# Epoch 1/6
# 2700/2700 [==============================] - 14s 5ms/step - loss: 0.5539 - acc: 0.7115
# Epoch 2/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.2176 - acc: 0.9093
# Epoch 3/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0898 - acc: 0.9681
# Epoch 4/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0467 - acc: 0.9822
# Epoch 5/6
# 2700/2700 [==============================] - 13s 5ms/step - loss: 0.0291 - acc: 0.9933
# Epoch 6/6
# 2700/2700 [==============================] - 14s 5ms/step - loss: 0.0169 - acc: 0.9996
# cross_validation score:  0.8800000007947286
# (400,)
# Running Fold 9 / 10
# Epoch 1/6
# 2700/2700 [==============================] - 16s 6ms/step - loss: 0.5506 - acc: 0.7259
# Epoch 2/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.2309 - acc: 0.9122
# Epoch 3/6
# 2700/2700 [==============================] - 598s 221ms/step - loss: 0.1102 - acc: 0.9622
# Epoch 4/6
# 2700/2700 [==============================] - 16s 6ms/step - loss: 0.0631 - acc: 0.9778
# Epoch 5/6
# 2700/2700 [==============================] - 12s 5ms/step - loss: 0.0447 - acc: 0.9878
# Epoch 6/6
# 2700/2700 [==============================] - 14s 5ms/step - loss: 0.0302 - acc: 0.9933
# cross_validation score:  0.9000000007947286
# (400,)
# Running Fold 10 / 10
# Epoch 1/6
# 2700/2700 [==============================] - 15s 5ms/step - loss: 0.5774 - acc: 0.6952
# Epoch 2/6
# 2700/2700 [==============================] - 12s 5ms/step - loss: 0.2298 - acc: 0.9000
# Epoch 3/6
# 2700/2700 [==============================] - 13s 5ms/step - loss: 0.0860 - acc: 0.9696
# Epoch 4/6
# 2700/2700 [==============================] - 13s 5ms/step - loss: 0.0504 - acc: 0.9785
# Epoch 5/6
# 2700/2700 [==============================] - 13s 5ms/step - loss: 0.0334 - acc: 0.9885
# Epoch 6/6
# 2700/2700 [==============================] - 12s 4ms/step - loss: 0.0210 - acc: 0.9937
# cross_validation score:  0.8933333333333333

# %%
avg_score2
# Out:
# [0.8966666668256125]
